# %%
import keras

from importlib import reload
from helpers import utils

# %%
TEST_IMAGE_DIR = "../../raw_datasets/BSDS300/images/test"

# %% [markdown]
# ### Load both models

# %%
irfan = keras.models.load_model(
    "models/saved/n2n_imagenet10k_05122024/irfan/50epochs.keras", 
    custom_objects={'psnr': utils.psnr},
    compile=False
)

unet = keras.models.load_model(
    "models/saved/n2n_imagenet10k_05122024/unet/50epochs.keras", 
    custom_objects={'psnr': utils.psnr},
    compile=False
)
# Out:
# 2024-12-07 14:49:57.848427: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2024-12-07 14:49:57.848455: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-12-07 14:49:57.848458: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-12-07 14:49:57.848598: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-12-07 14:49:57.848861: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
reload(utils)
ground_truth_fig, patches_fig = utils.compare_two_models_denoising(image_path=TEST_IMAGE_DIR + "/108005.jpg",
                                   model1=irfan, model2=unet, patch_coords=(160, 50),
                                   patch_size=192, zero_one_normalisation=True,
                                   greyscale=True, stddev=30, model1_name="Irfan", model2_name="U-Net")

ground_truth_fig.savefig("models/saved/n2n_imagenet10k_05122024/ground_truth_1.pdf")
patches_fig.savefig("models/saved/n2n_imagenet10k_05122024/irfan_vs_unet_1.pdf")
# Out:
# 1/1 [==============================] - 0s 289ms/step
# 2024-12-07 14:50:00.489786: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 244ms/step
# 2024-12-07 14:50:00.736054: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
reload(utils)
ground_truth_fig, patches_fig = utils.compare_two_models_denoising(image_path=TEST_IMAGE_DIR + "/148089.jpg",
                                   model1=irfan, model2=unet, patch_coords=(240, 110),
                                   patch_size=192, zero_one_normalisation=True,
                                   greyscale=True, stddev=30, model1_name="Irfan", model2_name="U-Net")

ground_truth_fig.savefig("models/saved/n2n_imagenet10k_05122024/ground_truth_2.pdf")
patches_fig.savefig("models/saved/n2n_imagenet10k_05122024/irfan_vs_unet_2.pdf")
# Out:
# ...
# 1/1 [==============================] - 0s 49ms/step
